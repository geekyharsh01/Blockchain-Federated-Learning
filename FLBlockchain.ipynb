# %%
# !git clone https://github.com/geekyharsh01/Blockchain-Federated-Learning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/hanglearning/VBFL

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Install pycryptodome and matplotlib
# !pip install pycryptodome==3.9.9 matplotlib


# Check if PyTorch is installed successfully
import torch
print(torch.__version__)

# Now you can run the code from the cloned repository in this environment
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 49.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pycryptodome: filename=pycryptodome-3.9.9-cp310-cp310-linux_x86_64.whl size=13645244 sha256=10312aa71f05d6b8f7955d50ea1e98e55ec63f3048c30c2c7afdbc8313ea7947
#   Stored in directory: /root/.cache/pip/wheels/49/5b/fb/dca47f0addc9751b38de3a949d0fc968150c3d31ee96faaf6f
# Successfully built pycryptodome
# ...
# 2.1.0+cu118

# %%
cd VBFL-master
# Out:
# /content/VBFL-master

# %%
ls
# Out:
# Blockchain.py  DatasetLoad.py  Models.py          README.md
# Block.py       Device.py       plotting_logs.zip  WHDY_vanilla_malicious_involved_fedavg/
# data/          main.py         plottings/

# %%
# !unzip plotting_logs.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: plotting_logs/PoS 3 20 0.08 diff # malicious nodes/12 5 3/nm8/comm_37/validator_device_13_M_validation_records_comm_37.txt
#   inflating: __MACOSX/plotting_logs/PoS 3 20 0.08 diff # malicious nodes/12 5 3/nm8/comm_37/._validator_device_13_M_validation_records_comm_37.txt
#   inflating: plotting_logs/PoS 3 20 0.08 diff # malicious nodes/12 5 3/nm8/comm_37/validator_device_15_B_validation_records_comm_37.txt
#   inflating: __MACOSX/plotting_logs/PoS 3 20 0.08 diff # malicious nodes/12 5 3/nm8/comm_37/._validator_device_15_B_validation_records_comm_37.txt
#   inflating: plotting_logs/PoS 3 20 0.08 diff # malicious nodes/12 5 3/nm8/comm_37/worker_device_3_B_local_updating_accuracies_comm_37.txt
#   inflating: __MACOSX/plotting_logs/PoS 3 20 0.08 diff # malicious nodes/12 5 3/nm8/comm_37/._worker_device_3_B_local_updating_accuracies_comm_37.txt
# ...

# %%
# cd VBFL-master

# %%
# !ls
# Out:
# Blockchain.py  DatasetLoad.py  Models.py	  README.md
# Block.py       Device.py       plotting_logs.zip  WHDY_vanilla_malicious_involved_fedavg
# data	       main.py	       plottings

# %%
# !nvidia-smi
# Out:
# Fri Nov 24 22:21:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python main.py -nd 20 -max_ncomm 30 -ha 12,5,3 -aio 1 -pow 0 -ko 6 -nm 3 -vh 0.08 -cs 0 -B 32 -mn mnist_cnn -iid 0 -lr 0.01 -dtx 1

# %% [markdown]
# Main code

# %%
# !python main.py -nd 20 -max_ncomm 100 -ha 15,3,2 -aio 1 -pow 0 -ko 6 -nm 2 -vh 0.08 -cs 0 -B 32 -mn mnist_cnn -iid 0 -lr 0.01 -dtx 1
# Out:
# Malicious nodes vs total devices set to 2/8 = 25.00%
# 0 GPUs are available to use!
# Extracting data/MNIST/train-images-idx3-ubyte.gz
# Extracting data/MNIST/train-labels-idx1-ubyte.gz
# Extracting data/MNIST/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST/t10k-labels-idx1-ubyte.gz
# Sharding dataset to device_1 done.
# Sharding dataset to device_2 done.
# Sharding dataset to device_3 done.
# Sharding dataset to device_4 done.
# Sharding dataset to device_5 done.
# Sharding dataset to device_6 done.
# Sharding dataset to device_7 done.
# Sharding dataset to device_8 done.
# Sharding dataset done!
#
# Communication round 1
# device_3 worker online - chain length 0
# device_4 worker online - chain length 0
# device_5 worker online - chain length 0
# device_1 worker online - chain length 0
# device_7 miner online - chain length 0
# device_6 miner online - chain length 0
# device_2 validator online - chain length 0
# device_8 validator online - chain length 0
#
# ...

# %%
# !python main.py -nd 8 -max_ncomm 4 -ha 3,3,2 -aio 1 -pow 0 -ko 3 -nm 1 -vh 0.08 -cs 0 -B 32 -mn mnist_cnn -iid 0 -lr 0.01 -dtx 1
# Out:
# Malicious nodes vs total devices set to 1/8 = 12.50%
# 1 GPUs are available to use!
# Extracting data/MNIST/train-images-idx3-ubyte.gz
# Extracting data/MNIST/train-labels-idx1-ubyte.gz
# Extracting data/MNIST/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST/t10k-labels-idx1-ubyte.gz
# Sharding dataset to device_1 done.
# Sharding dataset to device_2 done.
# Sharding dataset to device_3 done.
# Sharding dataset to device_4 done.
# Sharding dataset to device_5 done.
# Sharding dataset to device_6 done.
# Sharding dataset to device_7 done.
# Sharding dataset to device_8 done.
# Sharding dataset done!
#
# Communication round 1
# device_5 worker online - chain length 0
# device_8 worker online - chain length 0
# device_6 worker online - chain length 0
# device_3 miner online - chain length 0
# device_1 miner online - chain length 0
# device_2 validator online - chain length 0
# device_7 validator online - chain length 0
# device_4 validator online - chain length 0
#
# ...

# %%
# !pip install matplotlib

# %%
cd WHDY_vanilla_malicious_involved_fedavg/
# Out:
# /content/VBFL/WHDY_vanilla_malicious_involved_fedavg

# %%
# !python /content/VBFL/WHDY_vanilla_malicious_involved_fedavg/server.py -nc 8 -mn mnist_cnn -iid 0 -nm 3
# Out:
# Extracting data/MNIST/train-images-idx3-ubyte.gz
# Extracting data/MNIST/train-labels-idx1-ubyte.gz
# Extracting data/MNIST/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST/t10k-labels-idx1-ubyte.gz
# communicate round 1
# malicious client client_4 has added noise to its local updated weights before transmitting
# malicious client client_1 has added noise to its local updated weights before transmitting
# malicious client client_2 has added noise to its local updated weights before transmitting
#  Logging Accuracies by clients
# communicate round 2
# malicious client client_4 has added noise to its local updated weights before transmitting
# malicious client client_2 has added noise to its local updated weights before transmitting
# malicious client client_1 has added noise to its local updated weights before transmitting
#  Logging Accuracies by clients
# communicate round 3
# malicious client client_4 has added noise to its local updated weights before transmitting
# ...

# %%
cp -r /content/VBFL/data /content/VBFL/WHDY_vanilla_malicious_involved_fedavg/

# %%
import os

# Set the working directory
os.chdir("/content/VBFL/")

# %%
# %matplotlib inline

# %%
# !python /content/VBFL/plottings/f1_plot_graph_combine.py /content/plotting_logs/VFL_nm0/run1 /content/plotting_logs/VFL_nm3/run2 /content/plotting_logs/old_PoS_3_20_vh=0.08/run1

# %%
ls
# Out:
# Blockchain.py   Device.py  plotting_logs.zip  WHDY_vanilla_malicious_involved_fedavg/
# Block.py        logs/      plottings/
# data/           main.py    __pycache__/
# DatasetLoad.py  Models.py  README.md

# %%
# !python /content/VBFL/plottings/f1_plot_graph_combine.py /content/VBFL/logs/11242023_222237/comm_1
# Out:
# Traceback (most recent call last):
#   File "/content/VBFL/plottings/f1_plot_graph_combine.py", line 8, in <module>
#     log_folder_m = sys.argv[2]
# IndexError: list index out of range
